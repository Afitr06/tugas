# %% [markdown]
# <a href="https://colab.research.google.com/github/Afitr06/tugas/blob/main/oprasing%2Ccoontrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Muhamad Fitroh SOdikin
#2006164
#kelas A

import cv2
import numpy as np

img = cv2.imread("spiderman.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow("Gambar Original", img)
cv2.imshow("Gambar GrayScale", gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Bagian Baru

# %%
#Muhamad Fitroh SOdikin
#2006164
#kelas A


import numpy
import matplotlib.pyplot as plt
from copy import deepcopy
from PIL import Image

def getGrayColor (rgb) :
    return rgb[0]
def setGrayColor(color):
    return [color, color, color]

img = Image.open('spiderman.jpg')
img = numpy.asarray(img)

ct = deepcopy(img)

r1 = 100
s1 = 50
r2 = 150
s2 = 200

for i in range(len(img)):
    for j in range(len(img[i])):
        x = getGrayColor(img[i][j])
        if(0 <= x and x <= r1):
            ct [i][j] = setGrayColor(s1/r1 * x)
        elif(r1 < x and x <= r2):
            ct[i][j] = setGrayColor(((s2 - s1)/(r2 - r1)) * (x - r1) + s1)
        elif (r2 < x and x <= 255):
            ct[i][j] = setGrayColor(((255 - s2) / (255 - r2)) * (x - r2) + s2)

plt.subplot(2, 2, 1)
plt.imshow(img)
plt.subplot(2, 2, 2)
plt.imshow(ct)
plt.show()

# %%
#Muhamad Fitroh SOdikin
#2006164
#kelas A


import cv2 as cv2
import numpy as np

img = cv2.imread("images.jpg")
cv2.imshow("Original Image", img)
kernel = np.ones((5,5), np.uint8)
erosion = cv2.erode(img, kernel, iterations = 1)
cv2.imshow("erosion", erosion)

dilation = cv2.dilate(img, kernel, iterations= 1)
cv2.imshow("Dilasi", dilation)

kernell = np.ones((3,3), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernell)
cv2.imshow('Opening', opening)

closing = cv2. morphologyEx(img, cv2.MORPH_CLOSE, kernel)
cv2.imshow("Closing", closing)

gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
cv2.imshow("Gradient", gradient)

cv2.waitKey(0)
cv2.destroyAllWindows()
